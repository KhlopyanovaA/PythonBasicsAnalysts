# %% [markdown]
# <a href="https://colab.research.google.com/github/KhlopyanovaA/PythonBasicsAnalysts/blob/main/Seminar_4_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Визуальный анализ данных

# %% [markdown]
# # Задача 1
#
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# * 1.1. Скачать данные по ссылке https://www.kaggle.com/datasets/astronautelvis/kc-house-data
# * 1.2 Изучите стоимости недвижимости
# * 1.3 Изучите распределение квадратуры жилой
# * 1.4 Изучите распределение года постройки

# %% [markdown]
# - id - Уникальный ID для каждого дома
# - date - Дата продажи дома
# - price - Стоимость продажи дома
# - bedrooms - Кол-во спален
# - bathrooms - Кол-во ванных комнат (0.5 - туалет без душа)
# - sqft_living - Кв. метры жилые
# - sqft_lot - Кв. метры общие
# - floors - Кол-во этажей
# - waterfront - Есть набержная или нет
# - view - Значение от 0 до 4 насколько хороший вид
# - condition - Значение от 1 до 5 насколько хорошее состояние
# - grade - Значение от 1 до 13, где 1-3 плохая конструкция здания и дизайн, 7 - средний уровень конструкции и дизайна, 11-13 - высокое качество конструкции и дизайна
# - sqft_above - Кв. метры дома, которые находятся выше земли
# - sqft_basement - Кв. метры дома, которые находятся ниже земли
# - yr_built - Год постройки дома
# - yr_renovated - Год ремонта дома
# - zipcode - Индекс
# - lat - Широтма
# - long - Долгота
# - sqft_living15 - Кв. метры жилой площади у 15 соседей
# - sqft_lot15 - Кв. метры общей площади у 15 соседей

# %% [markdown]
# * 1.1. Скачать данные

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Считываем датасет
df = pd.read_csv('kc_house_data.csv', sep=',')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# * 1.2 Изучите стоимости недвижимости

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['price'])
plt.title('Стоимость')
plt.xlabel('Стоимость')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['price'])
plt.title('Распределение price')
plt.xlabel('Стоимость')
plt.ylabel('Количество');

# %% [markdown]
# * 1.3 Изучите распределение квадратуры жилой

# %%
counts = df['sqft_living'].value_counts()
plt.scatter(x=counts.index, y=counts.values)
plt.title('Номера')
plt.xlabel('Квадратура')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# * 1.4 Изучите распределение года постройки

# %%
counts = df['yr_built'].value_counts()
plt.scatter(x=counts.index, y=counts.values)
plt.title('Год постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# # Задача 2
# * 2.1 Изучите распределение домов от наличия вида на набережную Постройте график Сделайте выводы
# * 2.2 Изучите распределение этажей домов
# * 2.3 Изучите распределение состояния домов

# %% [markdown]
# * 2.1 Изучите распределение домов от наличия вида на набережную Постройте график Сделайте выводы

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=df['id'], y=df['waterfront'])

plt.figure(figsize=(16, 14))
sns.barplot(x=df['price'], y=df['waterfront'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='waterfront'>

# %% [markdown]
# * 2.2 Изучите распределение этажей домов

# %%
plt.figure(figsize=(10, 4))
sns.histplot(df['yr_renovated'])
plt.title('Распределние Год ремонта')
plt.xlabel('Год ремонта')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# * 2.3 Изучите распределение состояния домов

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['floors'])
plt.title('Распределние Этажей домов')
plt.xlabel('Номер этажа')
plt.ylabel('Количество')
# Много малоэтажных домов
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# # Задача 3
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
# Дома , находящиеся выше земли
counts = df['sqft_above'].value_counts()

plt.figure(figsize=(10, 4))
plt.title('sqft_above')
sns.barplot(x=counts.index, y=counts.values)

plt.show()

# %%
# С помощью столбиков анализируем еще и бинарные признаки(есть или нет).
# Вид из окна

counts = df['view'].value_counts()

plt.figure(figsize=(8, 6))
plt.title('view')
sns.barplot(x=counts.index, y=counts.values)

plt.show()

# %%
 # Зависимость Цены от года постройки дома, в котором они проживают.

sns.jointplot(x=df['price'], y=df['yr_built'], kind='reg');

# %%
# Изучаем широту.
# Где данные более скученные - там их больше.

sns.jointplot(x=df['lat'], y=df['long'], kind='kde'); # kind='kde' - другая отрисовка.

# %%
# Изучаем долготу.

sns.jointplot(x=df['lat'], y=df['price'], kind='reg'); # kind='reg' - точечный график.
# Цена от долготы
